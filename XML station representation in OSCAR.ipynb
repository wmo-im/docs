# %% [markdown]
# In this blog post we want to show how to create a station, change it and finally close it, using the XML representation of a station. First we will have a closer look at the XML file for a station, what characterizes a typical station in OSCAR (in this example a simple snyoptic station) and how is that represented in the XML file. The following Table lists the elements of our example station:
#
# | Metadata field | Example station | ID in XML file |
# |----|----|----|
# | Name | ST-PREX | |
# | Station type | Land (fixed) | |
# | WIGOS ID | 0-20000-0-06706 | id-wsi |
# | WMO region | VI - Europe | |
# | Territory | Switzerland | |
# | Coordinates | 46.4836111111°N, | id-coord |
# | <i></i> | 6.4430555556°E, | |
# | <i></i> | 425m | |
# | Supervising organization | MeteoSwiss | |
# | Program | GOS | |
# | Observation 1 | Humidity | |
# | Observation 2 | Precipitation | |
# | Observation 3 | Pressure | |
# | Observation 4 | Temperature | |
# | Observation 5 | Wind | |
# | Station contacts | Mr. XY | |

# %% [markdown]
# Now we want to create a XML file containing this information of our example station. Our XML file starts with a header. It contains the information about the XML version (1.0), the encoding (UTF-8) and the links for the metadata standard (?):

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <wmdr:WIGOSMetadataRecord xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:wmdr="http://def.wmo.int/wmdr/2017" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:ns6="http://def.wmo.int/opm/2013" xmlns:ns7="http://def.wmo.int/metce/2013" xmlns:om="http://www.opengis.net/om/2.0" xmlns:ns9="http://www.isotc211.org/2005/gts" xmlns:sam="http://www.opengis.net/sampling/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" gml:id="id_f64ee9c5-9fbd-4b54-9923-4184424c109d" xsi:schemaLocation="http://def.wmo.int/wmdr/2017 http://schemas.wmo.int/wmdr/1.0RC9/wmdr.xsd">
# ```

# %% [markdown]
# ? (das taucht an mehreren Stellen auf und kann ich irgendwie nicht richtig zuordnen etc.):

# %% [markdown]
# ```xml
# <gml:boundedBy xsi:nil="true"/>
# ```

# %% [markdown]
# Und das braucht man auch für den header?:

# %% [markdown]
# ```xml
#     <wmdr:headerInformation>
#         <wmdr:Header/>
#     </wmdr:headerInformation>
# ```

# %% [markdown]
# Next follows some information about the facility that we want to represent in our XML file. That is the WIGOS ID (gml:identifier) and station name (gml:name):

# %% [markdown]
# ```xml
# <wmdr:facility>
#     <wmdr:ObservingFacility gml:id="id-wsi">
#       <gml:identifier codeSpace="0-20000-0-06706">0-20000-0-06706</gml:identifier>
#       <gml:name>ST-PREX</gml:name>
# ```

# %% [markdown]
# The element gml:id is the internal id of the corresponding element, here our wigos station id (id-wsi). We need this internal id for each element in case we want to apply changes later on to a specific element. Without this id OSCAR does not know what needs to be changed when uploading a changed/new XML file and might therefore create a new entry instead of updating an old entry (see examples later). The ids for the corresponging elements are also given in the Table xy.
#
# Next, we want to add the supervising organization of the station. The wmdr element for that in the XML Standard is called responsibleParty, the role of this party has to be defined as well (here owner, refering to the corresponding codelist). The supervising organization has to be set for a certain time span (validPeriod), here starting at the 28.04.2016:

# %% [markdown]
# ```xml
# <wmdr:responsibleParty>
#     <wmdr:ResponsibleParty>
#         <wmdr:responsibleParty>
#             <gmd:CI_ResponsibleParty>
#               <gmd:organisationName>
# <gco:CharacterString>Federal Office of Meteorology and Climatology MeteoSwiss</gco:CharacterString>
#               </gmd:organisationName>
#               <gmd:role>
# <gmd:CI_RoleCode codeList="http://codes.wmo.int/wmdr/owner" codeListValue="owner"/>
#               </gmd:role>
#             </gmd:CI_ResponsibleParty>
#          </wmdr:responsibleParty>
#          <wmdr:validPeriod xlink:type="simple">
#             <gml:TimePeriod gml:id="id-time_orga">
#               <gml:beginPosition>2016-04-28T00:00:00.000+02:00</gml:beginPosition>
#               <gml:endPosition/>
#             </gml:TimePeriod>
#          </wmdr:validPeriod>
#          </wmdr:ResponsibleParty>
#        </wmdr:responsibleParty>
# ```

# %% [markdown]
# Now we define the location/coordinates of our station (gml:pos: lon, lat, height). Here as well we have to define for which time span this information is valid:

# %% [markdown]
# ```xml
# <wmdr:geospatialLocation>
#     <wmdr:GeospatialLocation>
#         <wmdr:geoLocation xlink:type="simple">
#             <gml:Point gml:id="id-coord">
#                <gml:pos>46.4836111111 6.4430555556 425.0
#                </gml:pos>
#             </gml:Point>
#         </wmdr:geoLocation>
#         <wmdr:validPeriod xlink:type="simple">
#             <gml:TimePeriod gml:id="id-time_coord">
#                 <gml:beginPosition>2016-04-28T00:00:00.000+02:00</gml:beginPosition>
#                 <gml:endPosition/>
#             </gml:TimePeriod>
#          </wmdr:validPeriod>
#      </wmdr:GeospatialLocation>
# </wmdr:geospatialLocation>
# ```

# %% [markdown]
# The station type is defined the following using the corresponding codelist:

# %% [markdown]
# ```xml
# <wmdr:facilityType xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/landFixed"/>
# ```

# %% [markdown]
# The WMO region uses as well a link to the corresponding codelist:

# %% [markdown]
# ```xml
# <wmdr:wmoRegion xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/europe"/>
# ```

# %% [markdown]
# We also add the territory of our station:

# %% [markdown]
# ```xml
# <wmdr:territory>
#     <wmdr:Territory>
#         <wmdr:territoryName xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/CHE"/>
#         <wmdr:validPeriod xlink:type="simple">
#             <gml:TimePeriod gml:id="id-time_territory">
#                 <gml:beginPosition>2016-04-28T00:00:00.000+02:00</gml:beginPosition>
#                 <gml:endPosition/>
#             </gml:TimePeriod>
#         </wmdr:validPeriod>
#     </wmdr:Territory>
# </wmdr:territory>
# ```

# %% [markdown]
# And the program affiliation (GOS, operational):

# %% [markdown]
# ```xml
# <wmdr:programAffiliation>
#     <wmdr:ProgramAffiliation>
#         <wmdr:programAffiliation xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/GOS"/>
#         <wmdr:reportingStatus>
#             <wmdr:ReportingStatus>
#                 <wmdr:reportingStatus xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/operational"/>
#                 <wmdr:validPeriod xlink:type="simple">
# <gml:TimePeriod gml:id="id-time_prog">
#     <gml:beginPosition>2016-04-28T00:00:00.000+02:00</gml:beginPosition>
#     <gml:endPosition/>
# </gml:TimePeriod>
#                 </wmdr:validPeriod>
#             </wmdr:ReportingStatus>
#         </wmdr:reportingStatus>
#     </wmdr:ProgramAffiliation>
# </wmdr:programAffiliation>
# ```

# %% [markdown]
# Observation 1:

# %% [markdown]
# ```xml
#             <wmdr:observation xlink:type="simple">
#                 <wmdr:ObservingCapability gml:id="id_4268ff21-9777-40e3-a4ce-b231a6c86057">
#                     <gml:boundedBy xsi:nil="true"/>
#                     <wmdr:facility xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/0-20000-0-06706"/>
#                     <wmdr:programAffiliation xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/GOS"/>
#                     <wmdr:observation xlink:type="simple">
#                         <om:OM_Observation gml:id="id_7e46ef13-2ebf-4a18-b59f-358b9e08641e">
#                             <gml:boundedBy xsi:nil="true"/>
#                             <om:type xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/point"/>
#                             <om:metadata xlink:type="simple">
# <gmd:MD_Metadata>
#     <gmd:contact xlink:type="simple">
#         <gmd:CI_ResponsibleParty>
#             <gmd:role/>
#         </gmd:CI_ResponsibleParty>
#     </gmd:contact>
#     <gmd:dateStamp>
#         <gco:Date xsi:nil="true"/>
#     </gmd:dateStamp>
#     <gmd:identificationInfo xlink:type="simple"/>
# </gmd:MD_Metadata>
#                             </om:metadata>
#                             <om:phenomenonTime xlink:type="simple"/>
#                             <om:resultTime xlink:type="simple"/>
#                             <om:procedure xlink:type="simple">
# <wmdr:Process gml:id="id_79dece1a-0215-4378-b13d-01230d73621a">
#     <gml:boundedBy xsi:nil="true"/>
#     <wmdr:deployment xlink:type="simple">
#         <wmdr:Deployment gml:id="id_b8503f05-f7f7-4066-a13c-1d8c40c89368">
#             <gml:boundedBy xsi:nil="true"/>
#             <wmdr:deployedEquipment xlink:type="simple">
#                 <wmdr:Equipment gml:id="id_c0b3c12a-bea2-4859-8261-9c67118689d2">
#                     <gml:boundedBy xsi:nil="true"/>
#                     <wmdr:responsibleParty>
#                         <wmdr:ResponsibleParty>
#                             <wmdr:responsibleParty>
# <gmd:CI_ResponsibleParty>
#     <gmd:role/>
# </gmd:CI_ResponsibleParty>
#                             </wmdr:responsibleParty>
#                         </wmdr:ResponsibleParty>
#                     </wmdr:responsibleParty>
#                     <wmdr:observingMethod xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/1"/>
#                     <wmdr:equipmentLog xlink:type="simple">
#                         <wmdr:EquipmentLog gml:id="id_cb6ce4be-ddb5-4439-ae03-e8d694199611">
#                             <gml:boundedBy xsi:nil="true"/>
#                             <wmdr:equipment xlink:type="simple"/>
#                         </wmdr:EquipmentLog>
#                     </wmdr:equipmentLog>
#                 </wmdr:Equipment>
#             </wmdr:deployedEquipment>
#             <wmdr:dataGeneration xlink:type="simple">
#                 <wmdr:DataGeneration gml:id="id_7072cb20-cdb1-49da-9632-00692c18df8b">
#                     <gml:boundedBy xsi:nil="true"/>
#                     <wmdr:validPeriod xlink:type="simple">
#                         <gml:TimePeriod gml:id="id_ed0bec0b-ec08-4fa3-a2ff-a89dcd2326c0">
#                             <gml:beginPosition/>
#                             <gml:endPosition/>
#                         </gml:TimePeriod>
#                     </wmdr:validPeriod>
#                     <wmdr:schedule/>
#                     <wmdr:sampling>
#                         <wmdr:Sampling/>
#                     </wmdr:sampling>
#                     <wmdr:reporting>
#                         <wmdr:Reporting>
#                             <wmdr:internationalExchange>false</wmdr:internationalExchange>
#                             <wmdr:uom xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/unknown"/>
#                             <wmdr:timeStampMeaning xlink:type="simple"/>
#                             <wmdr:dataPolicy>
# <wmdr:DataPolicy>
#     <wmdr:dataPolicy xlink:type="simple"/>
#     <wmdr:attribution>
#         <wmdr:Attribution>
#             <wmdr:originator>
#                 <gmd:CI_ResponsibleParty>
#                     <gmd:role/>
#                 </gmd:CI_ResponsibleParty>
#             </wmdr:originator>
#         </wmdr:Attribution>
#     </wmdr:attribution>
# </wmdr:DataPolicy>
#                             </wmdr:dataPolicy>
#                             <wmdr:referenceTimeSource xlink:type="simple"/>
#                             <wmdr:levelOfData xlink:type="simple"/>
#                             <wmdr:dataFormat xlink:type="simple"/>
#                         </wmdr:Reporting>
#                     </wmdr:reporting>
#                 </wmdr:DataGeneration>
#             </wmdr:dataGeneration>
#             <wmdr:validPeriod xlink:type="simple"/>
#             <wmdr:localReferenceSurface xlink:type="simple"/>
#             <wmdr:applicationArea xlink:type="simple"/>
#             <wmdr:sourceOfObservation xlink:type="simple"/>
#             <wmdr:exposure xlink:type="simple"/>
#         </wmdr:Deployment>
#     </wmdr:deployment>
# </wmdr:Process>
#                             </om:procedure>
#                             <om:observedProperty xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/251"/>
#                             <om:featureOfInterest xsi:nil="true"/>
#                             <om:result xlink:type="simple">
# <wmdr:ResultSet>
#     <wmdr:distributionInfo>
#         <gmd:MD_Distribution>
#             <gmd:distributor xlink:type="simple">
#                 <gmd:MD_Distributor>
#                     <gmd:distributorContact xlink:type="simple">
#                         <gmd:CI_ResponsibleParty>
#                             <gmd:role/>
#                         </gmd:CI_ResponsibleParty>
#                     </gmd:distributorContact>
#                 </gmd:MD_Distributor>
#             </gmd:distributor>
#         </gmd:MD_Distribution>
#     </wmdr:distributionInfo>
# </wmdr:ResultSet>
#                             </om:result>
#                         </om:OM_Observation>
#                     </wmdr:observation>
#                 </wmdr:ObservingCapability>
#             </wmdr:observation>
# ```

# %%
Observation 2:

# %%
                    <wmdr:observingMethod xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/1"/>
                    <wmdr:equipmentLog xlink:type="simple">
                        <wmdr:EquipmentLog gml:id="id_356aca7b-8e6d-4f39-995e-8f764a994031">
                            <gml:boundedBy xsi:nil="true"/>
                            <wmdr:equipment xlink:type="simple"/>
                        </wmdr:EquipmentLog>
                    </wmdr:equipmentLog>
                </wmdr:Equipment>
            </wmdr:deployedEquipment>
            <wmdr:dataGeneration xlink:type="simple">
                <wmdr:DataGeneration gml:id="id_a2c93a99-ef88-46de-83d1-b8a88a6ac6a2">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:validPeriod xlink:type="simple">
                        <gml:TimePeriod gml:id="id_b2052187-7344-4fa0-8b61-518d814b38a9">
                            <gml:beginPosition/>
                            <gml:endPosition/>
                        </gml:TimePeriod>
                    </wmdr:validPeriod>
                    <wmdr:schedule/>
                    <wmdr:sampling>
                        <wmdr:Sampling/>
                    </wmdr:sampling>
                    <wmdr:reporting>
                        <wmdr:Reporting>
                            <wmdr:internationalExchange>false</wmdr:internationalExchange>
                            <wmdr:uom xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/unknown"/>
                            <wmdr:timeStampMeaning xlink:type="simple"/>
                            <wmdr:dataPolicy>
<wmdr:DataPolicy>
    <wmdr:dataPolicy xlink:type="simple"/>
    <wmdr:attribution>
        <wmdr:Attribution>
            <wmdr:originator>
                <gmd:CI_ResponsibleParty>
                    <gmd:role/>
                </gmd:CI_ResponsibleParty>
            </wmdr:originator>
        </wmdr:Attribution>
    </wmdr:attribution>
</wmdr:DataPolicy>
                            </wmdr:dataPolicy>
                            <wmdr:referenceTimeSource xlink:type="simple"/>
                            <wmdr:levelOfData xlink:type="simple"/>
                            <wmdr:dataFormat xlink:type="simple"/>
                        </wmdr:Reporting>
                    </wmdr:reporting>
                </wmdr:DataGeneration>
            </wmdr:dataGeneration>
            <wmdr:validPeriod xlink:type="simple"/>
            <wmdr:localReferenceSurface xlink:type="simple"/>
            <wmdr:applicationArea xlink:type="simple"/>
            <wmdr:sourceOfObservation xlink:type="simple"/>
            <wmdr:exposure xlink:type="simple"/>
        </wmdr:Deployment>
    </wmdr:deployment>
</wmdr:Process>
                            </om:procedure>
                            <om:observedProperty xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/213"/>
                            <om:featureOfInterest xsi:nil="true"/>
                            <om:result xlink:type="simple">
<wmdr:ResultSet>
    <wmdr:distributionInfo>
        <gmd:MD_Distribution>
            <gmd:distributor xlink:type="simple">
                <gmd:MD_Distributor>
                    <gmd:distributorContact xlink:type="simple">
                        <gmd:CI_ResponsibleParty>
                            <gmd:role/>
                        </gmd:CI_ResponsibleParty>
                    </gmd:distributorContact>
                </gmd:MD_Distributor>
            </gmd:distributor>
        </gmd:MD_Distribution>
    </wmdr:distributionInfo>
</wmdr:ResultSet>
                            </om:result>
                        </om:OM_Observation>
                    </wmdr:observation>
                </wmdr:ObservingCapability>
            </wmdr:observation>

# %%
Observation 3:

# %%
            <wmdr:observation xlink:type="simple">
                <wmdr:ObservingCapability gml:id="id_89e258ba-880d-477d-8f87-6410723ae955">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:facility xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/0-20000-0-06706"/>
                    <wmdr:programAffiliation xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/GOS"/>
                    <wmdr:observation xlink:type="simple">
                        <om:OM_Observation gml:id="id_2b3f6d25-3f2d-4095-9ae5-efcce2a78985">
                            <gml:boundedBy xsi:nil="true"/>
                            <om:type xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/point"/>
                            <om:metadata xlink:type="simple">
<gmd:MD_Metadata>
    <gmd:contact xlink:type="simple">
        <gmd:CI_ResponsibleParty>
            <gmd:role/>
        </gmd:CI_ResponsibleParty>
    </gmd:contact>
    <gmd:dateStamp>
        <gco:Date xsi:nil="true"/>
    </gmd:dateStamp>
    <gmd:identificationInfo xlink:type="simple"/>
</gmd:MD_Metadata>
                            </om:metadata>
                            <om:phenomenonTime xlink:type="simple"/>
                            <om:resultTime xlink:type="simple"/>
                            <om:procedure xlink:type="simple">
<wmdr:Process gml:id="id_a32b0f26-08e5-4b54-8c0b-cb12e41e13e4">
    <gml:boundedBy xsi:nil="true"/>
    <wmdr:deployment xlink:type="simple">
        <wmdr:Deployment gml:id="id_995a19f7-2a3a-4781-843a-dc92fc730acc">
            <gml:boundedBy xsi:nil="true"/>
            <wmdr:deployedEquipment xlink:type="simple">
                <wmdr:Equipment gml:id="id_fef14ab3-c820-43ef-957f-d59bd739add1">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:responsibleParty>
                        <wmdr:ResponsibleParty>
                            <wmdr:responsibleParty>
<gmd:CI_ResponsibleParty>
    <gmd:role/>
</gmd:CI_ResponsibleParty>
                            </wmdr:responsibleParty>
                        </wmdr:ResponsibleParty>
                    </wmdr:responsibleParty>
                    <wmdr:observingMethod xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/1"/>
                    <wmdr:equipmentLog xlink:type="simple">
                        <wmdr:EquipmentLog gml:id="id_e4d69599-73a4-4347-b743-cf448851e03c">
                            <gml:boundedBy xsi:nil="true"/>
                            <wmdr:equipment xlink:type="simple"/>
                        </wmdr:EquipmentLog>
                    </wmdr:equipmentLog>
                </wmdr:Equipment>
            </wmdr:deployedEquipment>
            <wmdr:dataGeneration xlink:type="simple">
                <wmdr:DataGeneration gml:id="id_5ea01d60-2e4a-4442-abc0-755c1d54c878">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:validPeriod xlink:type="simple">
                        <gml:TimePeriod gml:id="id_8d1d2b8c-4a48-4dec-815c-267cf6a22f1f">
                            <gml:beginPosition/>
                            <gml:endPosition/>
                        </gml:TimePeriod>
                    </wmdr:validPeriod>
                    <wmdr:schedule/>
                    <wmdr:sampling>
                        <wmdr:Sampling/>
                    </wmdr:sampling>
                    <wmdr:reporting>
                        <wmdr:Reporting>
                            <wmdr:internationalExchange>false</wmdr:internationalExchange>
                            <wmdr:uom xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/unknown"/>
                            <wmdr:timeStampMeaning xlink:type="simple"/>
                            <wmdr:dataPolicy>
<wmdr:DataPolicy>
    <wmdr:dataPolicy xlink:type="simple"/>
    <wmdr:attribution>
        <wmdr:Attribution>
            <wmdr:originator>
                <gmd:CI_ResponsibleParty>
                    <gmd:role/>
                </gmd:CI_ResponsibleParty>
            </wmdr:originator>
        </wmdr:Attribution>
    </wmdr:attribution>
</wmdr:DataPolicy>
                            </wmdr:dataPolicy>
                            <wmdr:referenceTimeSource xlink:type="simple"/>
                            <wmdr:levelOfData xlink:type="simple"/>
                            <wmdr:dataFormat xlink:type="simple"/>
                        </wmdr:Reporting>
                    </wmdr:reporting>
                </wmdr:DataGeneration>
            </wmdr:dataGeneration>

# %%
Observation 4:

# %%
            <wmdr:validPeriod xlink:type="simple"/>
            <wmdr:localReferenceSurface xlink:type="simple"/>
            <wmdr:applicationArea xlink:type="simple"/>
            <wmdr:sourceOfObservation xlink:type="simple"/>
            <wmdr:exposure xlink:type="simple"/>
        </wmdr:Deployment>
    </wmdr:deployment>
</wmdr:Process>
                            </om:procedure>
                            <om:observedProperty xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/216"/>
                            <om:featureOfInterest xsi:nil="true"/>
                            <om:result xlink:type="simple">
<wmdr:ResultSet>
    <wmdr:distributionInfo>
        <gmd:MD_Distribution>
            <gmd:distributor xlink:type="simple">
                <gmd:MD_Distributor>
                    <gmd:distributorContact xlink:type="simple">
                        <gmd:CI_ResponsibleParty>
                            <gmd:role/>
                        </gmd:CI_ResponsibleParty>
                    </gmd:distributorContact>
                </gmd:MD_Distributor>
            </gmd:distributor>
        </gmd:MD_Distribution>
    </wmdr:distributionInfo>
</wmdr:ResultSet>
                            </om:result>
                        </om:OM_Observation>
                    </wmdr:observation>
                </wmdr:ObservingCapability>
            </wmdr:observation>
            <wmdr:observation xlink:type="simple">
                <wmdr:ObservingCapability gml:id="id_0c439915-e58c-45fb-9fcf-e12896ecd0ef">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:facility xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/0-20000-0-06706"/>
                    <wmdr:programAffiliation xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/GOS"/>
                    <wmdr:observation xlink:type="simple">
                        <om:OM_Observation gml:id="id_d69b0441-2626-4508-93cb-c5255cb2424a">
                            <gml:boundedBy xsi:nil="true"/>
                            <om:type xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/point"/>
                            <om:metadata xlink:type="simple">
<gmd:MD_Metadata>
    <gmd:contact xlink:type="simple">
        <gmd:CI_ResponsibleParty>
            <gmd:role/>
        </gmd:CI_ResponsibleParty>
    </gmd:contact>
    <gmd:dateStamp>
        <gco:Date xsi:nil="true"/>
    </gmd:dateStamp>
    <gmd:identificationInfo xlink:type="simple"/>
</gmd:MD_Metadata>
                            </om:metadata>
                            <om:phenomenonTime xlink:type="simple"/>
                            <om:resultTime xlink:type="simple"/>
                            <om:procedure xlink:type="simple">
<wmdr:Process gml:id="id_bd20c86b-f2b5-460b-bb9e-4173759bea76">
    <gml:boundedBy xsi:nil="true"/>
    <wmdr:deployment xlink:type="simple">
        <wmdr:Deployment gml:id="id_941ae063-f9a6-4bca-a42b-06686144d07d">
            <gml:boundedBy xsi:nil="true"/>
            <wmdr:deployedEquipment xlink:type="simple">
                <wmdr:Equipment gml:id="id_30992e5b-8866-4bc9-b732-4536f2262e23">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:responsibleParty>
                        <wmdr:ResponsibleParty>
                            <wmdr:responsibleParty>
<gmd:CI_ResponsibleParty>
    <gmd:role/>
</gmd:CI_ResponsibleParty>
                            </wmdr:responsibleParty>
                        </wmdr:ResponsibleParty>
                    </wmdr:responsibleParty>

# %%
Observation 5:

# %%
                    <wmdr:observingMethod xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/1"/>
                    <wmdr:equipmentLog xlink:type="simple">
                        <wmdr:EquipmentLog gml:id="id_6f0c968d-e037-4fdd-853e-41ceb7f04fa6">
                            <gml:boundedBy xsi:nil="true"/>
                            <wmdr:equipment xlink:type="simple"/>
                        </wmdr:EquipmentLog>
                    </wmdr:equipmentLog>
                </wmdr:Equipment>
            </wmdr:deployedEquipment>
            <wmdr:dataGeneration xlink:type="simple">
                <wmdr:DataGeneration gml:id="id_4cef5900-0fa8-45cd-8cce-d3614f7de955">
                    <gml:boundedBy xsi:nil="true"/>
                    <wmdr:validPeriod xlink:type="simple">
                        <gml:TimePeriod gml:id="id_a5d936eb-f56e-4fc7-8c42-624fbbe6c924">
                            <gml:beginPosition/>
                            <gml:endPosition/>
                        </gml:TimePeriod>
                    </wmdr:validPeriod>
                    <wmdr:schedule/>
                    <wmdr:sampling>
                        <wmdr:Sampling/>
                    </wmdr:sampling>
                    <wmdr:reporting>
                        <wmdr:Reporting>
                            <wmdr:internationalExchange>false</wmdr:internationalExchange>
                            <wmdr:uom xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/unknown"/>
                            <wmdr:timeStampMeaning xlink:type="simple"/>
                            <wmdr:dataPolicy>
<wmdr:DataPolicy>
    <wmdr:dataPolicy xlink:type="simple"/>
    <wmdr:attribution>
        <wmdr:Attribution>
            <wmdr:originator>
                <gmd:CI_ResponsibleParty>
                    <gmd:role/>
                </gmd:CI_ResponsibleParty>
            </wmdr:originator>
        </wmdr:Attribution>
    </wmdr:attribution>
</wmdr:DataPolicy>
                            </wmdr:dataPolicy>
                            <wmdr:referenceTimeSource xlink:type="simple"/>
                            <wmdr:levelOfData xlink:type="simple"/>
                            <wmdr:dataFormat xlink:type="simple"/>
                        </wmdr:Reporting>
                    </wmdr:reporting>
                </wmdr:DataGeneration>
            </wmdr:dataGeneration>
            <wmdr:validPeriod xlink:type="simple"/>
            <wmdr:localReferenceSurface xlink:type="simple"/>
            <wmdr:applicationArea xlink:type="simple"/>
            <wmdr:sourceOfObservation xlink:type="simple"/>
            <wmdr:exposure xlink:type="simple"/>
        </wmdr:Deployment>
    </wmdr:deployment>
</wmdr:Process>
                            </om:procedure>
                            <om:observedProperty xlink:type="simple" xlink:href="http://codes.wmo.int/wmdr/224"/>
                            <om:featureOfInterest xsi:nil="true"/>
                            <om:result xlink:type="simple">
<wmdr:ResultSet>
    <wmdr:distributionInfo>
        <gmd:MD_Distribution>
            <gmd:distributor xlink:type="simple">
                <gmd:MD_Distributor>
                    <gmd:distributorContact xlink:type="simple">
                        <gmd:CI_ResponsibleParty>
                            <gmd:role/>
                        </gmd:CI_ResponsibleParty>
                    </gmd:distributorContact>
                </gmd:MD_Distributor>
            </gmd:distributor>
        </gmd:MD_Distribution>
    </wmdr:distributionInfo>
</wmdr:ResultSet>
                            </om:result>
                        </om:OM_Observation>
                    </wmdr:observation>
                </wmdr:ObservingCapability>
            </wmdr:observation>

# %%
Observation 6:

# %% [markdown]
# The complete XML file for registering this test station can be found here:
